# %% [markdown]
# <a href="https://colab.research.google.com/github/chominyeong/2023_Manufacturing-BigData_Analytics_Competition/blob/main/Visualization_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import math
import scipy.stats as stats
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
import random
import itertools

import matplotlib.pyplot as plt
import seaborn as sns

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 행 : 튜브
# 열 : 샤프트

# %% [markdown]
# ### 등면적

# %%
등면적중앙mse = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med_mse.csv")
등면적중앙1st = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med_accuracy1.csv")
등면적중앙2nd = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med_accuracy2.csv")

# %%
등면적평균mse = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean_mse.csv")
등면적평균1st = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean_accuracy1.csv")
등면적평균2nd = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean_accuracy2.csv")

# %% [markdown]
# #### 중앙

# %%
###등면적 중앙###

fig, axs = plt.subplots(3, 1, figsize=(10, 8))
fig.suptitle('<equal area partitioning> Median - MSE, 1st accuracy, 2nd accuracy')

# MSE 그래프
axs[0].plot(list(itertools.chain(*np.array(등면적중앙mse))), marker='o')
axs[0].set_title('MSE')
axs[0].set_ylabel('MSE')

# Accuracy (Exact Match) 그래프
axs[1].plot(list(itertools.chain(*np.array(등면적중앙1st))), marker='o', color='orange')
axs[1].set_title('Accuracy (Exact Match)')
axs[1].set_ylabel('Accuracy')

# Accuracy (Within 0.002) 그래프
axs[2].plot(list(itertools.chain(*np.array(등면적중앙2nd))), marker='o', color='green')
axs[2].axhline(90, color='r', linestyle='--', linewidth=1)
axs[2].set_title('Accuracy (Within 0.002)')
axs[2].set_ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 평균

# %%
###등면적 평균###

fig, axs = plt.subplots(3, 1, figsize=(10, 8))
fig.suptitle('<equal area partitioning> MEAN - MSE, 1st accuracy, 2nd accuracy')

# MSE 그래프
axs[0].plot(list(itertools.chain(*np.array(등면적평균mse))), marker='o')
axs[0].set_title('MSE')
axs[0].set_xlabel('Configuration')
axs[0].set_ylabel('MSE')

# Accuracy (Exact Match) 그래프
axs[1].plot(list(itertools.chain(*np.array(등면적평균1st))), marker='o', color='orange')
axs[1].set_title('Accuracy (Exact Match)')
axs[1].set_xlabel('Configuration')
axs[1].set_ylabel('Accuracy')

# Accuracy (Within 0.002) 그래프
axs[2].plot(list(itertools.chain(*np.array(등면적평균2nd))), marker='o', color='green')
axs[2].axhline(90, color='r', linestyle='--', linewidth=1)
axs[2].set_title('Accuracy (Within 0.002)')
axs[2].set_xlabel('Configuration')
axs[2].set_ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 등간격

# %%
# 0.0001
등간격중앙mse1 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med1_mse.csv")
등간격중앙1st1 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med1_accuracy1.csv")
등간격중앙2nd1 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med1_accuracy2.csv")

# %%
# 0.0001
등간격평균mse1 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean1_mse.csv")
등간격평균1st1 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean1_accuracy1.csv")
등간격평균2nd1 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean1_accuracy2.csv")

# %%
# 0.001
등간격중앙mse2 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med2_mse.csv")
등간격중앙1st2 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med2_accuracy1.csv")
등간격중앙2nd2 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med2_accuracy2.csv")

# %%
# 0.001
등간격평균mse2 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean2_mse.csv")
등간격평균1st2 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean2_accuracy1.csv")
등간격평균2nd2 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean2_accuracy2.csv")

# %%
# 0.0013
등간격중앙mse3 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med3_mse.csv")
등간격중앙1st3= pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med3_accuracy1.csv")
등간격중앙2nd3 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Med3_accuracy2.csv")

# %%
# 0.0013
등간격평균mse3 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean3_mse.csv")
등간격평균1st3 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean3_accuracy1.csv")
등간격평균2nd3 = pd.read_csv("/content/drive/MyDrive/📌2023 제조 빅데이터 분석 경진대회/정확도/Mean3_accuracy2.csv")

# %% [markdown]
# #### 중앙

# %%
###등간격 중앙###

fig, axs = plt.subplots(3, 1, figsize=(12, 10))
fig.suptitle('<erqual width partitioning> MEDIAN - MSE, 1st accuracy, 2nd accuracy')

# MSE 그래프
axs[0].plot(list(itertools.chain(*np.array(등간격중앙mse1))), color='#e35f62', label='0.0001')
axs[0].plot(list(itertools.chain(*np.array(등간격중앙mse2))), color='#bcbd22', label='0.001')
axs[0].plot(list(itertools.chain(*np.array(등간격중앙mse3))), color='#17becf', label='0.0013')
axs[0].set_title('MSE')
axs[0].set_xlabel('Configuration')
axs[0].set_ylabel('MSE')
axs[0].legend(ncol=3)

# Accuracy (Exact Match) 그래프
axs[1].plot(list(itertools.chain(*np.array(등간격중앙1st1))), color='#e35f62')
axs[1].plot(list(itertools.chain(*np.array(등간격중앙1st2))), color='#bcbd22')
axs[1].plot(list(itertools.chain(*np.array(등간격중앙1st3))), color='#17becf')
axs[1].set_title('Accuracy (Exact Match)')
axs[1].set_xlabel('Configuration')
axs[1].set_ylabel('Accuracy')

# Accuracy (Within 0.002) 그래프
axs[2].plot(list(itertools.chain(*np.array(등간격중앙2nd1))), color='#e35f62')
axs[2].plot(list(itertools.chain(*np.array(등간격중앙2nd2))), color='#bcbd22')
axs[2].plot(list(itertools.chain(*np.array(등간격중앙2nd3))), color='#17becf')
axs[2].axhline(90, color='b', linestyle='--', linewidth=1)
axs[2].set_title('Accuracy (Within 0.002)')
axs[2].set_xlabel('Configuration')
axs[2].set_ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 평균

# %%
###등간격 평균###

fig, axs = plt.subplots(3, 1, figsize=(12, 10))
fig.suptitle('<erqual width partitioning> MEAN - MSE, 1st accuracy, 2nd accuracy')

# MSE 그래프
axs[0].plot(list(itertools.chain(*np.array(등간격평균mse1))), color='#e35f62', label='0.0001')
axs[0].plot(list(itertools.chain(*np.array(등간격평균mse2))), color='#bcbd22', label='0.001')
axs[0].plot(list(itertools.chain(*np.array(등간격평균mse3))), color='#17becf', label='0.0013')
axs[0].set_title('MSE')
axs[0].set_xlabel('Configuration')
axs[0].set_ylabel('MSE')
axs[0].legend(ncol=3)

# Accuracy (Exact Match) 그래프
axs[1].plot(list(itertools.chain(*np.array(등간격평균1st1))), color='#e35f62')
axs[1].plot(list(itertools.chain(*np.array(등간격평균1st2))), color='#bcbd22')
axs[1].plot(list(itertools.chain(*np.array(등간격평균1st3))), color='#17becf')
axs[1].set_title('Accuracy (Exact Match)')
axs[1].set_xlabel('Configuration')
axs[1].set_ylabel('Accuracy')

# Accuracy (Within 0.002) 그래프
axs[2].plot(list(itertools.chain(*np.array(등간격평균2nd1))), color='#e35f62')
axs[2].plot(list(itertools.chain(*np.array(등간격평균2nd2))), color='#bcbd22')
axs[2].plot(list(itertools.chain(*np.array(등간격평균2nd3))), color='#17becf')
axs[2].axhline(90, color='b', linestyle='--', linewidth=1)
axs[2].set_title('Accuracy (Within 0.002)')
axs[2].set_xlabel('Configuration')
axs[2].set_ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 등간격 0.0013 중앙& 평균

# %%
###등간격 평균###

fig, axs = plt.subplots(3, 1, figsize=(12, 10))
fig.suptitle('<erqual width partitioning> MEAN&MEDIAN - MSE, 1st accuracy, 2nd accuracy')

# MSE 그래프
axs[0].plot(list(itertools.chain(*np.array(등간격평균mse3))), color='dodgerblue', label='mean')
axs[0].plot(list(itertools.chain(*np.array(등간격중앙mse3))), color='limegreen', label='median')
axs[0].set_title('MSE')
axs[0].set_xlabel('Configuration')
axs[0].set_ylabel('MSE')
axs[0].legend(ncol=3)

# Accuracy (Exact Match) 그래프
axs[1].plot(list(itertools.chain(*np.array(등간격평균1st3))), color='dodgerblue')
axs[1].plot(list(itertools.chain(*np.array(등간격중앙1st3))), color='limegreen')
axs[1].axhline(90, color='r', linestyle='--', linewidth=1)
axs[1].set_title('Accuracy (Exact Match)')
axs[1].set_xlabel('Configuration')
axs[1].set_ylabel('Accuracy')

# Accuracy (Within 0.002) 그래프
axs[2].plot(list(itertools.chain(*np.array(등간격평균2nd3))), color='dodgerblue')
axs[2].plot(list(itertools.chain(*np.array(등간격중앙2nd3))), color='limegreen')
axs[2].axhline(90, color='r', linestyle='--', linewidth=1)
axs[2].set_title('Accuracy (Within 0.002)')
axs[2].set_xlabel('Configuration')
axs[2].set_ylabel('Accuracy')

plt.tight_layout()
plt.show()
